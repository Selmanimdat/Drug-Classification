# %% [markdown]
# # Drug Classification

# %%
#Drug Classification project

# %%
#!pip install pycaret

# %%
#libraries
import pandas as pd
from pycaret.classification import*
import seaborn as sns
import matplotlib.pyplot as plt
import joblib

# %%
#read data 
df=pd.read_csv("/kaggle/input/drug-classification/drug200.csv")
print(df.shape)
df.head()
# Out:
# (200, 6)
#    Age Sex      BP Cholesterol  Na_to_K   Drug
# 0   23   F    HIGH        HIGH   25.355  DrugY
# 1   47   M     LOW        HIGH   13.093  drugC
# 2   47   M     LOW        HIGH   10.114  drugC
# 3   28   F  NORMAL        HIGH    7.798  drugX
# 4   61   F     LOW        HIGH   18.043  DrugY

# %%
#EDA
df.corr(numeric_only=True)
# Out:
#               Age   Na_to_K
# Age      1.000000 -0.063119
# Na_to_K -0.063119  1.000000

# %%
df.describe()
# Out:
#               Age     Na_to_K
# count  200.000000  200.000000
# mean    44.315000   16.084485
# std     16.544315    7.223956
# min     15.000000    6.269000
# 25%     31.000000   10.445500
# 50%     45.000000   13.936500
# 75%     58.000000   19.380000
# max     74.000000   38.247000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          200 non-null    int64
#  1   Sex          200 non-null    object
#  2   BP           200 non-null    object
#  3   Cholesterol  200 non-null    object
#  4   Na_to_K      200 non-null    float64
#  5   Drug         200 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 9.5+ KB

# %%
df.isnull().sum()
# Out:
# Age            0
# Sex            0
# BP             0
# Cholesterol    0
# Na_to_K        0
# Drug           0
# dtype: int64

# %%
#data visualization
df["Sex"] = df["Sex"].astype("category")
sns.countplot(x="Sex", data=df);

# %%
df["Age"] = df["Age"].astype("category")
sns.histplot(x="Age", data=df);

# %%
df["Drug"] = df["Drug"].astype("category")
sns.countplot(x="Drug", data=df);

# %%
# setup data
setup(data=df,target="Drug")
# Out:
# <style type="text/css">
# #T_67a66_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_67a66">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_67a66_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_67a66_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_67a66_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_67a66_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_67a66_row0_col1" class="data row0 col1" >1855</td>
#     </tr>
#     <tr>
#       <th id="T_67a66_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_67a66_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_67a66_row1_col1" class="data row1 col1" >Drug</td>
#     </tr>
#     <tr>
#       <th id="T_67a66_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_67a66_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_67a66_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_67a66_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_67a66_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_67a66_row3_col1" class="data row3 col1" >DrugY: 0, drugA: 1, drugB: 2, drugC: 3, drugX: 4</td>
#     </tr>
#     <tr>
#       <th id="T_67a66_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_67a66_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_67a66_row4_col1" class="data row4 col1" >(200, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_67a66_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_67a66_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_67a66_row5_col1" class="data row5 col1" >(200, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_67a66_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_67a66_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_67a66_row6_col1" class="data row6 col1" >(140, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_67a66_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_67a66_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_67a66_row7_col1" class="data row7 col1" >(60, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_67a66_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_67a66_row8_col0" class="data row8 col0" >Ordinal features</td>
#       <td id="T_67a66_row8_col1" class="data row8 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_67a66_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_67a66_row9_col0" class="data row9 col0" >Numeric features</td>
#       <td id="T_67a66_row9_col1" class="data row9 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_67a66_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_67a66_row10_col0" class="data row10 col0" >Categorical features</td>
#       <td id="T_67a66_row10_col1" class="data row10 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_67a66_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_67a66_row11_col0" class="data row11 col0" >Preprocess</td>
#       <td id="T_67a66_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_67a66_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_67a66_row12_col0" class="data row12 col0" >Imputation type</td>
#       <td id="T_67a66_row12_col1" class="data row12 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_67a66_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_67a66_row13_col0" class="data row13 col0" >Numeric imputation</td>
#       <td id="T_67a66_row13_col1" class="data row13 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_67a66_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_67a66_row14_col0" class="data row14 col0" >Categorical imputation</td>
#       <td id="T_67a66_row14_col1" class="data row14 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_67a66_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_67a66_row15_col0" class="data row15 col0" >Maximum one-hot encoding</td>
#       <td id="T_67a66_row15_col1" class="data row15 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_67a66_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_67a66_row16_col0" class="data row16 col0" >Encoding method</td>
#       <td id="T_67a66_row16_col1" class="data row16 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_67a66_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_67a66_row17_col0" class="data row17 col0" >Fold Generator</td>
#       <td id="T_67a66_row17_col1" class="data row17 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_67a66_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_67a66_row18_col0" class="data row18 col0" >Fold Number</td>
#       <td id="T_67a66_row18_col1" class="data row18 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_67a66_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_67a66_row19_col0" class="data row19 col0" >CPU Jobs</td>
#       <td id="T_67a66_row19_col1" class="data row19 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_67a66_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_67a66_row20_col0" class="data row20 col0" >Use GPU</td>
#       <td id="T_67a66_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_67a66_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_67a66_row21_col0" class="data row21 col0" >Log Experiment</td>
#       <td id="T_67a66_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_67a66_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_67a66_row22_col0" class="data row22 col0" >Experiment Name</td>
#       <td id="T_67a66_row22_col1" class="data row22 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_67a66_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_67a66_row23_col0" class="data row23 col0" >USI</td>
#       <td id="T_67a66_row23_col1" class="data row23 col1" >69d4</td>
#     </tr>
#   </tbody>
# </table>

# %%
#compare models
compare_models()
# Out:
# <style type="text/css">
# #T_ffc79 th {
#   text-align: left;
# }
# #T_ffc79_row0_col0, #T_ffc79_row0_col2, #T_ffc79_row0_col7, #T_ffc79_row1_col0, #T_ffc79_row1_col2, #T_ffc79_row1_col4, #T_ffc79_row1_col5, #T_ffc79_row1_col6, #T_ffc79_row2_col0, #T_ffc79_row2_col2, #T_ffc79_row2_col4, #T_ffc79_row2_col5, #T_ffc79_row2_col6, #T_ffc79_row2_col7, #T_ffc79_row3_col0, #T_ffc79_row3_col1, #T_ffc79_row3_col2, #T_ffc79_row3_col3, #T_ffc79_row3_col4, #T_ffc79_row3_col5, #T_ffc79_row3_col6, #T_ffc79_row3_col7, #T_ffc79_row4_col0, #T_ffc79_row4_col1, #T_ffc79_row4_col2, #T_ffc79_row4_col3, #T_ffc79_row4_col4, #T_ffc79_row4_col5, #T_ffc79_row4_col6, #T_ffc79_row4_col7, #T_ffc79_row5_col0, #T_ffc79_row5_col1, #T_ffc79_row5_col3, #T_ffc79_row5_col4, #T_ffc79_row5_col5, #T_ffc79_row5_col6, #T_ffc79_row5_col7, #T_ffc79_row6_col0, #T_ffc79_row6_col1, #T_ffc79_row6_col2, #T_ffc79_row6_col3, #T_ffc79_row6_col4, #T_ffc79_row6_col5, #T_ffc79_row6_col6, #T_ffc79_row6_col7, #T_ffc79_row7_col0, #T_ffc79_row7_col1, #T_ffc79_row7_col2, #T_ffc79_row7_col3, #T_ffc79_row7_col4, #T_ffc79_row7_col5, #T_ffc79_row7_col6, #T_ffc79_row7_col7, #T_ffc79_row8_col0, #T_ffc79_row8_col1, #T_ffc79_row8_col2, #T_ffc79_row8_col3, #T_ffc79_row8_col4, #T_ffc79_row8_col5, #T_ffc79_row8_col6, #T_ffc79_row8_col7, #T_ffc79_row9_col0, #T_ffc79_row9_col1, #T_ffc79_row9_col2, #T_ffc79_row9_col3, #T_ffc79_row9_col4, #T_ffc79_row9_col5, #T_ffc79_row9_col6, #T_ffc79_row9_col7, #T_ffc79_row10_col0, #T_ffc79_row10_col1, #T_ffc79_row10_col2, #T_ffc79_row10_col3, #T_ffc79_row10_col4, #T_ffc79_row10_col5, #T_ffc79_row10_col6, #T_ffc79_row10_col7, #T_ffc79_row11_col0, #T_ffc79_row11_col1, #T_ffc79_row11_col2, #T_ffc79_row11_col3, #T_ffc79_row11_col4, #T_ffc79_row11_col5, #T_ffc79_row11_col6, #T_ffc79_row11_col7, #T_ffc79_row12_col0, #T_ffc79_row12_col1, #T_ffc79_row12_col2, #T_ffc79_row12_col3, #T_ffc79_row12_col4, #T_ffc79_row12_col5, #T_ffc79_row12_col6, #T_ffc79_row12_col7, #T_ffc79_row13_col0, #T_ffc79_row13_col1, #T_ffc79_row13_col2, #T_ffc79_row13_col3, #T_ffc79_row13_col4, #T_ffc79_row13_col5, #T_ffc79_row13_col6, #T_ffc79_row13_col7, #T_ffc79_row14_col0, #T_ffc79_row14_col1, #T_ffc79_row14_col2, #T_ffc79_row14_col3, #T_ffc79_row14_col4, #T_ffc79_row14_col5, #T_ffc79_row14_col6, #T_ffc79_row14_col7, #T_ffc79_row15_col0, #T_ffc79_row15_col1, #T_ffc79_row15_col2, #T_ffc79_row15_col3, #T_ffc79_row15_col4, #T_ffc79_row15_col5, #T_ffc79_row15_col6, #T_ffc79_row15_col7 {
#   text-align: left;
# }
# #T_ffc79_row0_col1, #T_ffc79_row0_col3, #T_ffc79_row0_col4, #T_ffc79_row0_col5, #T_ffc79_row0_col6, #T_ffc79_row1_col1, #T_ffc79_row1_col3, #T_ffc79_row1_col7, #T_ffc79_row2_col1, #T_ffc79_row2_col3, #T_ffc79_row5_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_ffc79_row0_col8, #T_ffc79_row1_col8, #T_ffc79_row2_col8, #T_ffc79_row3_col8, #T_ffc79_row4_col8, #T_ffc79_row5_col8, #T_ffc79_row6_col8, #T_ffc79_row7_col8, #T_ffc79_row8_col8, #T_ffc79_row10_col8, #T_ffc79_row11_col8, #T_ffc79_row12_col8, #T_ffc79_row13_col8, #T_ffc79_row14_col8, #T_ffc79_row15_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_ffc79_row9_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_ffc79">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ffc79_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ffc79_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_ffc79_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_ffc79_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_ffc79_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_ffc79_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_ffc79_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_ffc79_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_ffc79_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ffc79_level0_row0" class="row_heading level0 row0" >dt</th>
#       <td id="T_ffc79_row0_col0" class="data row0 col0" >Decision Tree Classifier</td>
#       <td id="T_ffc79_row0_col1" class="data row0 col1" >0.9143</td>
#       <td id="T_ffc79_row0_col2" class="data row0 col2" >0.9495</td>
#       <td id="T_ffc79_row0_col3" class="data row0 col3" >0.9143</td>
#       <td id="T_ffc79_row0_col4" class="data row0 col4" >0.8974</td>
#       <td id="T_ffc79_row0_col5" class="data row0 col5" >0.9007</td>
#       <td id="T_ffc79_row0_col6" class="data row0 col6" >0.8772</td>
#       <td id="T_ffc79_row0_col7" class="data row0 col7" >0.8824</td>
#       <td id="T_ffc79_row0_col8" class="data row0 col8" >0.0790</td>
#     </tr>
#     <tr>
#       <th id="T_ffc79_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_ffc79_row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#       <td id="T_ffc79_row1_col1" class="data row1 col1" >0.9143</td>
#       <td id="T_ffc79_row1_col2" class="data row1 col2" >0.9895</td>
#       <td id="T_ffc79_row1_col3" class="data row1 col3" >0.9143</td>
#       <td id="T_ffc79_row1_col4" class="data row1 col4" >0.8949</td>
#       <td id="T_ffc79_row1_col5" class="data row1 col5" >0.8991</td>
#       <td id="T_ffc79_row1_col6" class="data row1 col6" >0.8762</td>
#       <td id="T_ffc79_row1_col7" class="data row1 col7" >0.8826</td>
#       <td id="T_ffc79_row1_col8" class="data row1 col8" >0.1990</td>
#     </tr>
#     <tr>
#       <th id="T_ffc79_level0_row2" class="row_heading level0 row2" >catboost</th>
#       <td id="T_ffc79_row2_col0" class="data row2 col0" >CatBoost Classifier</td>
#       <td id="T_ffc79_row2_col1" class="data row2 col1" >0.9143</td>
#       <td id="T_ffc79_row2_col2" class="data row2 col2" >0.9851</td>
#       <td id="T_ffc79_row2_col3" class="data row2 col3" >0.9143</td>
#       <td id="T_ffc79_row2_col4" class="data row2 col4" >0.8939</td>
#       <td id="T_ffc79_row2_col5" class="data row2 col5" >0.8983</td>
#       <td id="T_ffc79_row2_col6" class="data row2 col6" >0.8762</td>
#       <td id="T_ffc79_row2_col7" class="data row2 col7" >0.8816</td>
#       <td id="T_ffc79_row2_col8" class="data row2 col8" >1.7560</td>
#     </tr>
#     <tr>
#       <th id="T_ffc79_level0_row3" class="row_heading level0 row3" >lr</th>
#       <td id="T_ffc79_row3_col0" class="data row3 col0" >Logistic Regression</td>
#       <td id="T_ffc79_row3_col1" class="data row3 col1" >0.9071</td>
#       <td id="T_ffc79_row3_col2" class="data row3 col2" >0.9875</td>
#       <td id="T_ffc79_row3_col3" class="data row3 col3" >0.9071</td>
#       <td id="T_ffc79_row3_col4" class="data row3 col4" >0.8867</td>
#       <td id="T_ffc79_row3_col5" class="data row3 col5" >0.8931</td>
#       <td id="T_ffc79_row3_col6" class="data row3 col6" >0.8653</td>
#       <td id="T_ffc79_row3_col7" class="data row3 col7" >0.8698</td>
#       <td id="T_ffc79_row3_col8" class="data row3 col8" >0.5760</td>
#     </tr>
#     <tr>
#       <th id="T_ffc79_level0_row4" class="row_heading level0 row4" >xgboost</th>
#       <td id="T_ffc79_row4_col0" class="data row4 col0" >Extreme Gradient Boosting</td>
#       <td id="T_ffc79_row4_col1" class="data row4 col1" >0.9000</td>
#       <td id="T_ffc79_row4_col2" class="data row4 col2" >0.9861</td>
#       <td id="T_ffc79_row4_col3" class="data row4 col3" >0.9000</td>
#       <td id="T_ffc79_row4_col4" class="data row4 col4" >0.8964</td>
#       <td id="T_ffc79_row4_col5" class="data row4 col5" >0.8923</td>
#       <td id="T_ffc79_row4_col6" class="data row4 col6" >0.8570</td>
#       <td id="T_ffc79_row4_col7" class="data row4 col7" >0.8633</td>
#       <td id="T_ffc79_row4_col8" class="data row4 col8" >0.1170</td>
#     </tr>
#     <tr>
#       <th id="T_ffc79_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_ffc79_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_ffc79_row5_col1" class="data row5 col1" >0.8929</td>
#       <td id="T_ffc79_row5_col2" cl
# Processing:   0%|          | 0/69 [00:00<?, ?it/s]
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        random_state=1855, splitter='best')

# %%
#cros over best model
best_model = create_model('dt')
# Out:
# <style type="text/css">
# #T_91085_row10_col0, #T_91085_row10_col1, #T_91085_row10_col2, #T_91085_row10_col3, #T_91085_row10_col4, #T_91085_row10_col5, #T_91085_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_91085">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_91085_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_91085_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_91085_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_91085_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_91085_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_91085_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_91085_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_91085_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_91085_row0_col0" class="data row0 col0" >1.0000</td>
#       <td id="T_91085_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_91085_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_91085_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_91085_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_91085_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_91085_row0_col6" class="data row0 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_91085_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_91085_row1_col0" class="data row1 col0" >0.9286</td>
#       <td id="T_91085_row1_col1" class="data row1 col1" >0.9615</td>
#       <td id="T_91085_row1_col2" class="data row1 col2" >0.9286</td>
#       <td id="T_91085_row1_col3" class="data row1 col3" >0.8929</td>
#       <td id="T_91085_row1_col4" class="data row1 col4" >0.9048</td>
#       <td id="T_91085_row1_col5" class="data row1 col5" >0.8906</td>
#       <td id="T_91085_row1_col6" class="data row1 col6" >0.8977</td>
#     </tr>
#     <tr>
#       <th id="T_91085_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_91085_row2_col0" class="data row2 col0" >0.9286</td>
#       <td id="T_91085_row2_col1" class="data row2 col1" >0.9615</td>
#       <td id="T_91085_row2_col2" class="data row2 col2" >0.9286</td>
#       <td id="T_91085_row2_col3" class="data row2 col3" >0.8929</td>
#       <td id="T_91085_row2_col4" class="data row2 col4" >0.9048</td>
#       <td id="T_91085_row2_col5" class="data row2 col5" >0.8906</td>
#       <td id="T_91085_row2_col6" class="data row2 col6" >0.8977</td>
#     </tr>
#     <tr>
#       <th id="T_91085_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_91085_row3_col0" class="data row3 col0" >1.0000</td>
#       <td id="T_91085_row3_col1" class="data row3 col1" >1.0000</td>
#       <td id="T_91085_row3_col2" class="data row3 col2" >1.0000</td>
#       <td id="T_91085_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_91085_row3_col4" class="data row3 col4" >1.0000</td>
#       <td id="T_91085_row3_col5" class="data row3 col5" >1.0000</td>
#       <td id="T_91085_row3_col6" class="data row3 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_91085_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_91085_row4_col0" class="data row4 col0" >0.8571</td>
#       <td id="T_91085_row4_col1" class="data row4 col1" >0.9167</td>
#       <td id="T_91085_row4_col2" class="data row4 col2" >0.8571</td>
#       <td id="T_91085_row4_col3" class="data row4 col3" >0.8571</td>
#       <td id="T_91085_row4_col4" class="data row4 col4" >0.8571</td>
#       <td id="T_91085_row4_col5" class="data row4 col5" >0.8028</td>
#       <td id="T_91085_row4_col6" class="data row4 col6" >0.8028</td>
#     </tr>
#     <tr>
#       <th id="T_91085_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_91085_row5_col0" class="data row5 col0" >0.9286</td>
#       <td id="T_91085_row5_col1" class="data row5 col1" >0.9583</td>
#       <td id="T_91085_row5_col2" class="data row5 col2" >0.9286</td>
#       <td id="T_91085_row5_col3" class="data row5 col3" >0.8810</td>
#       <td id="T_91085_row5_col4" class="data row5 col4" >0.9000</td>
#       <td id="T_91085_row5_col5" class="data row5 col5" >0.9007</td>
#       <td id="T_91085_row5_col6" class="data row5 col6" >0.9072</td>
#     </tr>
#     <tr>
#       <th id="T_91085_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_91085_row6_col0" class="data row6 col0" >0.9286</td>
#       <td id="T_91085_row6_col1" class="data row6 col1" >0.9583</td>
#       <td id="T_91085_row6_col2" class="data row6 col2" >0.9286</td>
#       <td id="T_91085_row6_col3" class="data row6 col3" >0.8810</td>
#       <td id="T_91085_row6_col4" class="data row6 col4" >0.9000</td>
#       <td id="T_91085_row6_col5" class="data row6 col5" >0.8978</td>
#       <td id="T_91085_row6_col6" class="data row6 col6" >0.9045</td>
#     </tr>
#     <tr>
#       <th id="T_91085_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_91085_row7_col0" class="data row7 col0" >0.8571</td>
#       <td id="T_91085_row7_col1" class="data row7 col1" >0.8958</td>
#       <td id="T_91085_row7_col2" class="data row7 col2" >0.8571</td>
#       <td id="T_91085_row7_col3" class="data row7 col3" >0.8197</td>
#       <td id="T_91085_row7_col4" class="data row7 col4" >0.8262</td>
#       <td id="T_91085_row7_col5" class="data row7 col5" >0.7926</td>
#       <td id="T_91085_row7_col6" class="data row7 col6" >0.8051</td>
#     </tr>
#     <tr>
#       <th id="T_91085_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_91085_row8_col0" class="data row8 col0" >0.9286</td>
#       <td id="T_91085_row8_col1" class="data row8 col1" >0.9615</td>
#       <td id="T_91085_row8_col2" class="data row8 col2" >0.9286</td>
#       <td id="T_91085_row8_col3" class="data row8 col3" >0.9643</td>
#       <td id="T_91085_row8_col4" class="data row8 col4" >0.9286</td>
#       <td id="T_91085_row8_col5" class="data row8 col5" >0.8993</td>
#       <td id="T_91085_row8_col6" class="data row8 col6" >0.9058</td>
#     </tr>
#     <tr>
#       <th id="T_91085_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_91085_row9_col0" class="data row9 col0" >0.7857</td>
#       <td id="T_91085_row9_col1" class="data row9 col1" >0.8814</td>
#       <td id="T_91085_row9_col2" class="data row9 col2" >0.7857</td>
#       <td id="T_91085_row9_col3" class="data row9 col3" >0.7857</td>
#       <td id="T_91085_row9_col4" class="data row9 col4" >0.7857</td>
#       <td id="T_91085_row9_col5" class="data row9 col5" >0.6978</td>
#       <td id="T_91085_row9_col6" class="data row9 col6" >0.7029</td>
#     </tr>
#     <tr>
#       <th id="T_91085_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_91085_row10_col0" class="data row10 col0" >0.9143</td>
#       <td id="T_91085_row10_col1" class="data row10 col1" >0.9495</td>
#       <td id="T_91085_row10_col2" class="data row10 col2" >0.9143</td>
#       <td id="T_91085_row10_col3" class="data row10 col3" >0.8974</td>
#       <td id="T_91085_row10_col4" class="data row10 col4" >0.9007</td>
#       <td id="T_91085_row10_col5" class="data row10 col5" >0.8772</td>
#       <td id="T_91085_row10_col6" class="data row10 col6" >0.8824</td>
#     </tr>
#     <tr>
#       <th id="T_91085_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_91085_row11_col0" class="data row11 col0" >0.0623</td>
#       <td id="T_91085_row11_col1" class="data row11 col1" >0.0378</td>
#       <td id="T_91085_row11_col2" class="data row11 col2" >0.0623</td>
#       <td id="T_91085_row11_col3" class="data row11 col3" >0.0680</td>
#       <td id="T_91085_row11_col4
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
#save model
joblib.dump(best_model,"model.joblib")
# Out:
# ['model.joblib']

# %%
#sources

# %% [markdown]
# -Zafer Acar Notes
